# %%
import pandas as pd
import quantstats as qs

# %%
# quantitative analysis
qs.extend_pandas()
amzn_analysis = qs.utils.download_returns('AMZN')
qs.reports.full(amzn_analysis, "XLY")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               1998-12-23   1998-12-23
# End Period                 2023-11-10   2023-11-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             99.0%        100.0%
#
# Cumulative Return          533.72%      5,243.84%
# CAGR﹪                     5.25%        11.66%
#
# Sharpe                     0.44         0.56
# Prob. Sharpe Ratio         98.55%       99.78%
# Smart Sharpe               0.43         0.56
# Sortino                    0.62         0.87
# Smart Sortino              0.61         0.86
# Sortino/√2                 0.44         0.62
# Smart Sortino/√2           0.43         0.61
# Omega                      1.12         1.12
#
# ...

# %%
contraction_portfolio_tickers = {
    'UHN': .09,
    'PFE': .09,
    'ABT': .09,
    'AEE': .09,
    'DUK': .09,
    'SO': .09,
    'PG': .09,
    'KO': .09,
    'COST': .09,
    'WMT': .09,
    'AMZN': .01,
    'TSLA': .01,
    'MCD': .01,
    'TM': .01,
    'MSFT': .01,
    'AAPL': .01,
    'GOOGL': .01,
    'JPM': .01,
    'BAC': .01,
    'TRST': .01
}

# %%
contraction_portfolio = qs.utils.make_index(contraction_portfolio_tickers)

qs.reports.full(contraction_portfolio, "SPY", period='3y')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
expansion_portfolio_tickers = {
    'UHN': .01,
    'PFE': .01,
    'ABT': .01,
    'AEE': .01,
    'DUK': .01,
    'SO': .01,
    'PG': .01,
    'KO': .01,
    'COST': .01,
    'WMT': .01,
    'AMZN': .09,
    'TSLA': .09,
    'MCD': .09,
    'TM': .09,
    'MSFT': .09,
    'AAPL': .09,
    'GOOGL': .09,
    'JPM': .09,
    'BAC': .09,
    'TRST': .09
}

# %%
expansion_portfolio = qs.utils.make_index(expansion_portfolio_tickers)

qs.reports.full(expansion_portfolio, "SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
tsla_analysis = qs.utils.download_returns('TSLA')
qs.reports.full(tsla_analysis, 'SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2010-07-01   2010-07-01
# End Period                 2023-11-10   2023-11-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          326.86%      13,411.33%
# CAGR﹪                     7.78%        28.83%
#
# Sharpe                     0.71         0.93
# Prob. Sharpe Ratio         99.5%        99.97%
# Smart Sharpe               0.71         0.93
# Sortino                    1.0          1.41
# Smart Sortino              1.0          1.41
# Sortino/√2                 0.71         1.0
# Smart Sortino/√2           0.7          1.0
# Omega                      1.18         1.18
#
# ...
